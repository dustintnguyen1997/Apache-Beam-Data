# %%
# Install necessary libraries
# !pip install pandas sweetviz

# Import libraries
import pandas as pd
import sweetviz

# Load the dataset (replace with the correct path or download using Kaggle API)
df = pd.read_csv('supermarket_sales.csv')

# Generate Sweetviz Report
report = sweetviz.analyze(df)
report.show_html("supermarket_sales_report.html")  # Generates an HTML file for viewing

# Display the report link
from IPython.display import HTML
HTML("supermarket_sales_report.html")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 80.6 MB/s eta 0:00:00
# ...
#                                              |          | [  0%]   00:00 -> (? left)
# Report supermarket_sales_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# <!doctype html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <link rel="icon" href="data:image/x-icon;base64,..." type="image/x-icon" />
#         <script> /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...
